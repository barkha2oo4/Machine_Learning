# %%
import pandas as pd
# two ways to read data either by right clicking on Raw in github or by coppying link from address bar and substitute blob with raw
#to read any file we can just use pd.read_*('') where * is the type of file you want to read i.e. pd.read_xml('')
titanic = pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.csv')

# %% [markdown]
# functions we will focus on is  -- .head() , .info() , .describe()

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
titanic.describe()

# %% [markdown]
# # Machine Learning
# ### INPUT + OUTPUT  -----> Rules
# ### Traditiponal programing
# INPUT + Rules -----> OUTPUT
#
# ### Analysis v/s Analytics
# nalysis deals with events that have already happened, while analytics steps on past and current data, and is primarily forward-looking.
# ### Types OF Analytics
# What happened
# Why did it HAppen
# What will happen
# How can we prevent/make it
#
# ### Variable in Machine Learning
# Variable which we want to predict is called Dependent Variable/ Target Variable / Output Variable/y
# Variable which help in prediction is called Independent Variable/ Attribute / Input Variable/ Feature/X
# ## Types Of Machine Learning
# ### Supervised Learning (y and X) -- trained on labeled dataset
# >> Regression algo is used for continuous values such as price, salary, age
# >> Classification used for discrete values or categorical
# ### Unsupervised Learning (only X) -- trained on unlabeled dataset
# >>Clustering: Clustering is a method of grouping the objects into clusters such that objects with most similarities remains into a group and has less or no similarities with the objects of another group. Cluster analysis finds the commonalities between the data objects and categorizes them as per the presence and absence of those commonalities.
# >>Association: An association rule is an unsupervised learning method which is used for finding the relationships between variables in the large database. It determines the set of items that occurs together in the dataset. Association rule makes marketing strategy more effective. Such as people who buy X item (suppose a bread) are also tend to purchase Y (Butter/Jam) item. A typical example of Association rule is Market Basket Analysis.
# >>Anomaly detection: Anomaly detection is a process of finding those rare items, data points, events, or observations that make suspicions by being different from the rest data points or observations. Anomaly detection is also known as outlier detection.
# >>PCA: Principal Component Analysis is an unsupervised learning algorithm that is used for the dimensionality reduction in machine learning. It is a statistical process that converts the observations of correlated features into a set of linearly uncorrelated features with the help of orthogonal transformation. These new transformed features are called the Principal Components.applications of PCA are image processing, movie recommendation system, optimizing the power allocation in various communication channels
# ### Reinforcement
# >>In Reinforcement Learning, the agent learns automatically using feedbacks without any labeled data, unlike supervised learning.
# Since there is no labeled data, so the agent is bound to learn by its experience only.
# RL solves a specific type of problem where decision making is sequential, and the goal is long-term, such as game-playing, robotics, etc.
# The agent interacts with the environment and explores it by itself. The primary goal of an agent in reinforcement learning is to improve the performance by getting the maximum positive rewards.
# The agent learns with the process of hit and trial, and based on the experience, it learns to perform the task in a better way. Hence, we can say that "Reinforcement learning is a type of machine learning method where an intelligent agent (computer program) interacts with the environment and learns to act within that." How a Robotic dog learns the movement of his arms is an example of Reinforcement learning.

# %%
import pandas as pd

# %%
salary=pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Salary%20Data.csv')

# %%
salary.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience Years  40 non-null     float64
#  1   Salary            40 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 768.0 bytes

# %%
salary.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
salary.columns
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
salary.shape
# Out:
# (40, 2)

# %% [markdown]
# What is Artificial Intelligence >> MAchine Learning >> Deep Learning ?
# [link text](https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.simplilearn.com%2Ftutorials%2Fartificial-intelligence-tutorial%2Fai-vs-machine-learning-vs-deep-learning&psig=AOvVaw37r2-7EMl38EDLJCGuP8HK&ust=1720900588139000&source=images&cd=vfe&opi=89978449&ved=0CBEQjRxqFwoTCPiOo7WkoocDFQAAAAAdAAAAABAJ)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Types of Machine Learning

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Supervised Learning
# **Rainfall(in mm)/Cricket_Score/Share_price ** **bold text**->continuous -- Regression
#
#
# **Exam_REsult(Pass or Fail)/ Vehicle_ON_Road(Car or Truck or 2whealer)/Win_in_MAtch** ->Categorical Value -- Classification

# %%
#Step 3: Define  target(y) and features (X)
# y(dependent)    X(independent)
#Exp               Salary (with increasing the salary Experience won't increase)   --- Thus this is wrong
#Salary            Exp    (with increasing the  Experience the salary also increase) --- Thus this is right
'''   THUS,Salary =y
Experience= X'''

# %%
y=salary['Salary']
X=salary[['Experience Years']]

# %%
salary.shape
# Out:
# (40, 2)

# %%
print(X.shape)
print(y.shape)
# Out:
# (40, 1)
# (40,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,train_size=0.7,random_state=2529)   #0.7 signify 70 percent
X_train
# Out:
#     Experience Years
# 28               6.5
# 31               7.9
# 34               8.7
# 20               4.7
# 4                2.0
# 3                1.5
# 18               4.3
# 26               6.0
# 2                1.3
# 22               5.1
# 35               9.0
# 7                2.9
# 39              10.5
# 30               7.1
# 10               3.2
# 0                1.1
# 9                3.2
# 13               3.8
# 5                2.2
# 37               9.6
# 23               5.3
# 25               5.9
# 21               4.9
# 24               5.5
# 8                3.0
# 36               9.5
# 15               4.0
# 32               8.2

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((28, 1), (12, 1), (28,), (12,))

# %% [markdown]
# # Ordinary Least Square Method /Linear Regression

# %%
#Step 3: define target(y) and features(X)
salary.columns
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
y=salary['Salary']
X=salary[['Experience Years']]
#step 4:Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=2529)

# %%
#Step 5:select model          #implementing a graph in a way that it shows the logic behind the relation b/w salary and exp. -->Predictive Modeling
'''Best_Fit_Line -> it help inpredicting the salary based on its experience for linear regression
e(error)= y_actual -y_pred
Best_Fit_Line=e1^2+e2^2+--------en^2=(Ee^2)= always minimum
y= c+mx                c=intercept  and m=slope
'''
#if we want to solve this using other model then
''' 1st- Geometry --> KNN Regression
    2nd- Entropy --> Decision Tree Regression'''
# Out:
# ' 1st- Geometry --> KNN Regression\n    2nd- Entropy --> Decision Tree Regression'

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
#step 6: rain model(fit model)
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 27010.963630394683

# %%
model.coef_
# Out:
# array([9343.3671387])

# %%
#step7: prediction
y_pred=model.predict(X_test)

# %%
#Salary=27010.9+9343.4*Experience
27010.9+9343.4*6.8
# Out:
# 90546.01999999999

# %%
X_test
# Out:
#     Experience Years
# 29               6.8
# 11               3.5
# 33               8.5
# 16               4.0
# 19               4.5
# 38              10.3
# 27               6.2
# 14               3.9
# 17               4.1
# 12               3.7

# %%
#step 8: Accuracy
''' e=y_actual-y_prediction
for accuracy either we find mean of absolute error or mean of square error or mean absolute percentage error'''

# %%
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(y_test,y_pred)  #e=6%
# Out:
# 0.06230870755908321
